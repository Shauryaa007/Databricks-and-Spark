# %%
df = spark.read.table("samples.bakehouse.sales_franchises")
df.display()

# %%
df.write.saveAsTable("test.test_schema.sales_franchises")

# %%
df1 = df.limit(5)
df1.count()

# %%
df1.printSchema()

# %%
df2 = spark.read.option("multiLine", "true").json("/Volumes/test/test_schema/test_volume/sales_multi_line.json")
df2.display()

# %%
df2.write.json("/Volumes/test/test_schema/test_volume/sales_multi_line_output.json")

# %%
df2.write.csv("/Volumes/test/test_schema/test_volume/sales_multi_line_output_csv.json", mode='overwrite')
