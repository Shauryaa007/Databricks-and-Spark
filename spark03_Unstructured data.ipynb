# %%
df = spark.read.text('/Volumes/test/test_schema/test_volume/logs/')
df.display()

# %%
df = spark.read.text('/Volumes/test/test_schema/test_volume/logs/', wholetext=True)
df.display()

# %%
df = spark.read.format('binaryFile').load('/Volumes/test/test_schema/test_volume/logs/')
df.display()

# %%
df = spark.read.text('/Volumes/test/test_schema/test_volume/logs/', wholetext=True)
df2= df.selectExpr('value','_metadata.file_path','_metadata.file_name','_metadata.file_size','_metadata.file_modification_time')
df2.display()
